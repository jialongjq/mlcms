# %% [markdown]
# # Task 2

# %% [markdown]
# ## Imports

# %%
from utils import *
# %load_ext autoreload
# %autoreload 2

# %%
bifurcation_diagram('alpha - x**2', -1, 1, 0.001)

# %%
bifurcation_diagram('alpha - 2*(x**2) - 3.', -20, 20, 0.1)
